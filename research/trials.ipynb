# %%
# config box
d = {"key":"val", "key1":"val1"}

# %%
d['key1']
# Out:
# 'val1'

# %%
from box import ConfigBox
# using this we can access dictionary d.key like that
d2 = ConfigBox({"key": "val", "key1": "val1"})

# %%
d2.key
# Out:
# 'val'

# %%
type(d2)
# Out:
# box.config_box.ConfigBox

# %%
type(d)
# Out:
# dict

# %%
# ensure annotations
def get_predict(x:int, y:int) -> int:
    return x*y

# %%
get_predict(x=2, y="3")   #still getting output although input is wrong
# Out:
# '33'

# %%
get_predict(x=2, y=3)
# Out:
# 6

# %%
from ensure import ensure_annotations

# %%
@ensure_annotations
def get_prodict_ensure(x:int, y:int) -> int:
    return x*y

# %%
# get_prodict_ensure(x=2, y="3")   #get error

# %%
get_prodict_ensure(x=2, y=3)
# Out:
# 6

# %% [markdown]
# ## Download data from Google Drive

# %%
import gdown

# %%
url="https://drive.google.com/file/d/1wlHzYz0gUQv7g4xy_Q2nO1-aD_8kulEU/view?usp=sharing"

# %%
file_id = url.split("/")[-2]
file_id
# Out:
# '1wlHzYz0gUQv7g4xy_Q2nO1-aD_8kulEU'

# %%
prefix = 'https://drive.google.com/uc?/export=download&id='
gdown.download(prefix+file_id, "Train-CT-KIDNEY-DATASET-Normal-Tumor.zip")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 2
#       1 prefix = 'https://drive.google.com/uc?/export=download&id='
# ----> 2 gdown.download(prefix+file_id, "Train-CT-KIDNEY-DATASET-Normal-Tumor.zip")
#
# NameError: name 'gdown' is not defined
